-- %%
SELECT * FROM Doctors;
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.022
-- <table><tr><th>Name</th><th>Specialty</th><th>Clinic_Name</th><th>City</th><th>State_Province</th><th>Country</th><th>Postal_Zip_Code</th><th>Website</th></tr><tr><td>Dr Jun Lin</td><td>ENT</td><td>Unity Health Toronto - St. Michael&#39;s Hospital</td><td>Toronto</td><td>Ontario</td><td>Canada</td><td>M5B 1W8</td><td>https://otolaryngology.utoronto.ca/faculty/r-jun-lin</td></tr><tr><td>Dr Who</td><td>ENT</td><td>Other clinic</td><td>Vancouver</td><td>British Columbia</td><td>Canada</td><td>M9C 1P2</td><td>NULL</td></tr></table>

-- %%
SELECT * FROM Doctors_Old;

-- %%
-- change table name
EXEC sp_rename 'Doctors', 'Doctors_Old2';
-- Out:
-- Caution: Changing any part of an object name could break scripts and stored procedures.
-- Total execution time: 00:00:00.072

-- %%
SELECT * FROM Doctors 
WHERE City LIKE 'Toronto' OR Postal_Zip_Code LIKE 'Toronto'

-- SELECT * FROM Doctors 
-- WHERE Specialty LIKE 'ENT'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.029
-- <table><tr><th>Name</th><th>Specialty</th><th>Clinic_Name</th><th>City</th><th>State_Province</th><th>Country</th><th>Postal_Zip_Code</th><th>Website</th></tr><tr><td>Dr Jun Lin</td><td>ENT</td><td>Unity Health Toronto - St. Michael&#39;s Hospital</td><td>Toronto</td><td>Ontario</td><td>Canada</td><td>M5B 1W8</td><td>https://otolaryngology.utoronto.ca/faculty/r-jun-lin</td></tr></table>
